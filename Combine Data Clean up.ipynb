# %%
import pandas as pd

import requests
import json
import os

# %%
combine1_csv = "nfl resources/NFL Combine 2017 - Quantitative.csv"

combine2_csv = "nfl resources/Combine_data_2018-2008.csv"

combine3_csv = "nfl resources/Combine_data_2000-2007.csv"

combine1 = pd.read_csv(combine_csv)
combine2 = pd.read_csv(combine2_csv)
combine3 = pd.read_csv(combine3_csv)
combine1
# Out:
#                   Player             College Position Pos Order    ID Grade  \
# 0      Mitchell Trubisky      North Carolina       QB         0  QB14   6.7
# 1         Deshaun Watson             Clemson       QB         0  QB15  6.27
# 2        Patrick Mahomes          Texas Tech       QB         0  QB10   5.9
# 3          DeShone Kizer          Notre Dame       QB         0  QB06  5.88
# 4        Nathan Peterman          Pittsburgh       QB         0  QB11  5.85
# 5             Brad Kaaya               Miami       QB         0  QB04  5.62
# 6             Davis Webb          California       QB         0  QB16   5.3
# 7           Joshua Dobbs           Tennessee       QB         0  QB02  5.15
# 8            Cooper Rush    Central Michigan       QB         0  QB12  5.13
# 9          C.J. Beathard                Iowa       QB         0  QB01  5.05
# 10           Sefo Liufau            Colorado       QB         0  QB09  4.89
# ...

# %%
combine2
# Out:
#         Rk    Year             Player  Pos     AV               School  \
# 0      NaN     NaN                NaN  NaN    NaN                  NaN
# 1      1.0  2018.0     Logan Woodside   QB    NaN               Toledo
# 2      2.0  2018.0      Mason Rudolph   QB    NaN         Oklahoma St.
# 3      3.0  2018.0         Josh Rosen   QB    NaN                 UCLA
# 4      4.0  2018.0     Baker Mayfield   QB    NaN             Oklahoma
# 5      5.0  2018.0       Chase Litton   QB    NaN             Marshall
# 6      6.0  2018.0      Lamar Jackson   QB    NaN           Louisville
# 7      7.0  2018.0     Riley Ferguson   QB    NaN              Memphis
# 8      8.0  2018.0          Luke Falk   QB    NaN       Washington St.
# 9      9.0  2018.0        Sam Darnold   QB    NaN                  USC
# 10    10.0  2018.0       Kurt Benkert   QB    NaN             Virginia
# 11    11.0  2018.0       J.T. Barrett   QB    NaN             Ohio St.
# ...

# %%
combine3
# Out:
#       Rk  Year              Player Pos     AV               School  \
# 0      1  2007     Isaiah Stanback  QB    0.0           Washington
# 1      2  2007        Drew Stanton  QB   10.0       Michigan State
# 2      3  2007          Troy Smith  QB    6.0           Ohio State
# 3      4  2007    JaMarcus Russell  QB    6.0                  LSU
# 4      5  2007           Jeff Rowe  QB    0.0               Nevada
# 5      6  2007         Brady Quinn  QB    2.0           Notre Dame
# 6      7  2007       Jordan Palmer  QB    0.0        Texas-El Paso
# 7      8  2007         Tyler Palko  QB    2.0           Pittsburgh
# 8      9  2007          Kevin Kolb  QB   13.0              Houston
# 9     10  2007      Matt Gutierrez  QB    0.0          Idaho State
# 10    11  2007       Trent Edwards  QB   18.0             Stanford
# 11    12  2007           John Beck  QB    4.0                  BYU
# 12    13  2007     Jared Zabransky  QB    NaN          Boise State
# ...

# %%
merged_combine_2_and_3 = pd.merge(combine2, combine3, on= "Pos")

# %%
merged_combine_2_and_3
# Out:
#         Rk_x  Year_x        Player_x Pos  AV_x    School_x      College_x  \
# 0        1.0  2018.0  Logan Woodside  QB   NaN      Toledo  College Stats
# 1        1.0  2018.0  Logan Woodside  QB   NaN      Toledo  College Stats
# 2        1.0  2018.0  Logan Woodside  QB   NaN      Toledo  College Stats
# 3        1.0  2018.0  Logan Woodside  QB   NaN      Toledo  College Stats
# 4        1.0  2018.0  Logan Woodside  QB   NaN      Toledo  College Stats
# 5        1.0  2018.0  Logan Woodside  QB   NaN      Toledo  College Stats
# 6        1.0  2018.0  Logan Woodside  QB   NaN      Toledo  College Stats
# 7        1.0  2018.0  Logan Woodside  QB   NaN      Toledo  College Stats
# 8        1.0  2018.0  Logan Woodside  QB   NaN      Toledo  College Stats
# 9        1.0  2018.0  Logan Woodside  QB   NaN      Toledo  College Stats
# 10       1.0  2018.0  Logan Woodside  QB   NaN      Toledo  College Stats
# 11       1.0  2018.0  Logan Woodside  QB   NaN      Toledo  College Stats
# ...
